# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,6))
sns.set(style='whitegrid')

# %%
df = pd.read_csv('demand_forecasting.csv')
df.head()
# Out:
#          Date Store ID Product ID     Category Region  Inventory Level  \
# 0  2022-01-01     S001      P0001  Electronics  North              195
# 1  2022-01-01     S001      P0002     Clothing  North              117
# 2  2022-01-01     S001      P0003     Clothing  North              247
# 3  2022-01-01     S001      P0004  Electronics  North              139
# 4  2022-01-01     S001      P0005    Groceries  North              152
#
#    Units Sold  Units Ordered  Price  Discount Weather Condition  Promotion  \
# 0         102            252  72.72         5             Snowy          0
# 1         117            249  80.16        15             Snowy          1
# 2         114            612  62.94        10             Snowy          1
# 3          45            102  87.63        10             Snowy          0
# 4          65            271  54.41         0             Snowy          0
#
#    Competitor Pricing Seasonality  Epidemic  Demand
# 0               85.73      Winter         0     115
# 1               92.02      Winter         0     229
# 2               60.08      Winter         0     157
# 3               85.19      Winter         0      52
# 4               51.63      Winter         0      59

# %%
df.shape
# Out:
# (76000, 16)

# %%
cols = ['Category','Region','Discount','Weather Condition','Promotion','Seasonality','Epidemic']
for col in cols:
    print(df[col].value_counts())
# Out:
# Category
# Groceries      30400
# Furniture      13680
# Clothing       12160
# Toys           10640
# Electronics     9120
# Name: count, dtype: int64
# Region
# North    30400
# South    15200
# East     15200
# West     15200
# Name: count, dtype: int64
# Discount
# 10    23298
# 0     17126
# 5     16918
# 15     6245
# 25     6222
# 20     6191
# Name: count, dtype: int64
# Weather Condition
# Cloudy    24360
# Sunny     22980
# Rainy     17500
# Snowy     11160
# Name: count, dtype: int64
# Promotion
# 0    51000
# 1    25000
# Name: count, dtype: int64
# Seasonality
# Winter    21000
# Spring    18400
# Summer    18400
# Autumn    18200
# Name: count, dtype: int64
# Epidemic
# 0    60800
# 1    15200
# Name: count, dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum().sum()
# Out:
# np.int64(0)

# %%
df.describe().round(2)
# Out:
#        Inventory Level  Units Sold  Units Ordered     Price  Discount  \
# count         76000.00    76000.00       76000.00  76000.00  76000.00
# mean            301.06       88.83          89.09     67.73      9.09
# std             226.51       43.99         162.40     39.38      7.48
# min               0.00        0.00           0.00      4.74      0.00
# 25%             136.00       58.00           0.00     32.00      5.00
# 50%             227.00       84.00           0.00     64.50     10.00
# 75%             408.00      114.00         121.00     95.83     10.00
# max            2267.00      426.00        1616.00    228.03     25.00
#
#        Promotion  Competitor Pricing  Epidemic    Demand
# count   76000.00            76000.00   76000.0  76000.00
# mean        0.33               69.45       0.2    104.32
# std         0.47               40.94       0.4     46.96
# min         0.00                4.29       0.0      4.00
# 25%         0.00               32.62       0.0     71.00
# 50%         0.00               65.70       0.0    100.00
# 75%         1.00               97.93       0.0    133.00
# max         1.00              261.22       1.0    430.00

# %%
sns.kdeplot(df['Demand'],color='blue')
sns.kdeplot(df['Units Sold'],color='red')
# Out:
# <Axes: xlabel='Demand', ylabel='Density'>
